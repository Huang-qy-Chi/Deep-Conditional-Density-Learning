# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FormatStrFormatter

# %%
misrate_linear = {
    'DL': [0.08675,	0.06452,	0.04374],
    'L1-PLS': [0.06706,	0.05221,	0.03942],
    'RDL': [0.07277,	0.05474,	0.04042], 
    'SDL': [0.44563,	0.43521,	0.38083], 
    'OLS': [0.05872,	0.04558,	0.02974],
    'DLS': [0.10981,	0.08194,	0.05867],
    'Proposed': [0.10117,	0.07871,	0.05548]
}
sample_sizes = ['500', '1000', '2000']
markers = ['o','^','+','>','<','v','D']
colors = ['green','black','magenta','brown','purple','blue','red']
plt.figure(figsize=(3, 6))
for i, (model_name, misrate) in enumerate(misrate_linear.items()):
    plt.plot(sample_sizes, misrate, marker = markers[i],color=colors[i], label=model_name)
plt.title('Case Linear', fontsize = 14)
plt.xlabel('Sample Size (n)', fontsize = 12)
plt.ylabel('Misspecification Rate (w)', fontsize = 12)
plt.xticks(sample_sizes)
# yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
plt.grid(True, linestyle='--',alpha=0.7)
plt.show()

# %%
regret_linear = {
    'DL': [0.01101,	0.00609,	0.00230],
    'L1-PLS': [0.00534,	0.00262,	0.00127],
    'RDL': [0.00654,	0.00329,	0.00148], 
    'SDL': [0.18835,	0.18057,	0.14619], 
    'OLS': [0.00488,	0.00255,	0.00102],
    'DLS': [0.01692,	0.00934,	0.00490],
    'Proposed': [0.01465,	0.00853,	0.00379]
}
sample_sizes = ['500', '1000', '2000']
markers = ['o','^','+','>','<','v','D']
colors = ['green','black','magenta','brown','purple','blue','red']
plt.figure(figsize=(3, 6))
for i, (model_name, misrate) in enumerate(regret_linear.items()):
    plt.plot(sample_sizes, misrate, marker = markers[i],color=colors[i], label=model_name)
plt.title('Case Linear', fontsize = 14)
plt.xlabel('Sample Size (n)', fontsize = 12)
plt.ylabel('Regret Value', fontsize = 12)
plt.xticks(sample_sizes)
plt.legend()
plt.grid(True, linestyle='--',alpha=0.7)
plt.show()

# %%
misrate_deep = {
    'DL': [0.32417,	0.30885,	0.30290],
    'L1-PLS': [0.30820,	0.30418,	0.30044],
    'RDL': [0.32302,	0.31774,	0.31103], 
    'SDL': [0.33025,	0.31291,	0.30448], 
    'OLS': [0.31092,	0.30684,	0.30196],
    'DLS': [0.20622,	0.12623,	0.08460],
    'Proposed': [0.18842,	0.11793,	0.08301]
}
sample_sizes = ['500', '1000', '2000']
markers = ['o','^','+','>','<','v','D']
colors = ['green','black','magenta','brown','purple','blue','red']
plt.figure(figsize=(3, 6))
for i, (model_name, misrate) in enumerate(misrate_deep.items()):
    plt.plot(sample_sizes, misrate, marker = markers[i],color=colors[i], label=model_name)
plt.title('Case Deep', fontsize = 14)
plt.xlabel('Sample Size (n)', fontsize = 12)
plt.ylabel('Misspecification Rate (w)', fontsize = 12)
plt.xticks(sample_sizes)
plt.legend()
plt.grid(True, linestyle='--',alpha=0.7)
plt.show()

# %%
regret_deep = {
    'DL': [0.10760,	0.09642,	0.09009],
    'L1-PLS': [0.09605,	0.09299,	0.08944],
    'RDL': [0.10628,	0.10256,	0.09756], 
    'SDL': [0.10906,	0.09820,	0.09220], 
    'OLS': [0.09667,	0.09416,	0.08906],
    'DLS': [0.06069,	0.02712,	0.01223],
    'Proposed': [0.04736,	0.02199,	0.01178]
}
sample_sizes = ['500', '1000', '2000']
markers = ['o','^','+','>','<','v','D']
colors = ['green','black','magenta','brown','purple','blue','red']
plt.figure(figsize=(3, 6))
for i, (model_name, misrate) in enumerate(regret_deep.items()):
    plt.plot(sample_sizes, misrate, marker = markers[i],color=colors[i], label=model_name)
plt.title('Case Deep', fontsize = 14)
plt.xlabel('Sample Size (n)', fontsize = 12)
plt.ylabel('Regret Value', fontsize = 12)
plt.xticks(sample_sizes)
plt.legend()
plt.grid(True, linestyle='--',alpha=0.7)
plt.show()
